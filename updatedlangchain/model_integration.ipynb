# %% [markdown]
# ##### Models Integration with OpenAI, Google Gemini and GROQ

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# ### For OpenAI
# from langchain.chat_models import init_chat_model
# model=init_chat_model("gpt-4.1)
#
# model
#
# ### Invoke the model
# model.invoke("Hello how are you?")
#
# response.content

# %%
###Google Gemini Model
from langchain.chat_models import init_chat_model
model=init_chat_model("google_genai:gemini-2.5-flash-lite")
response=model.invoke("Why do parrots talk?")
response.content
# Out:
# 'Parrots talk for a fascinating and multifaceted combination of reasons, rooted in their biology, social nature, and cognitive abilities. It\'s not just about mimicking sounds; it\'s a complex form of communication and social interaction.\n\nHere are the primary reasons why parrots talk:\n\n**1. Social Bonding and Communication:**\n\n* **Flock Integration:** In the wild, parrots are highly social animals that live in large flocks. Vocalizations are crucial for maintaining contact within the flock, especially when foraging or flying. They use calls to identify each other, signal danger, locate food sources, and coordinate group movements.\n* **Strengthening Social Bonds:** Talking, or mimicking sounds, can be an extension of this social behavior. By mimicking sounds and associating them with individuals or objects, they can "participate" in the social environment of their flock (or their human family). This can strengthen their bond with their group.\n* **Seeking Attention and Interaction:** For parrots, especially in captivity, talking is a way to get attention from their flock members (which are their human owners). They learn that making sounds, especially those that resemble human speech, elicits a response, which is highly rewarding for a social animal.\n\n**2. Cognitive Abilities and Intelligence:**\n\n* **Learning and Mimicry:** Parrots are incredibly intelligent birds with remarkable learning capabilities. They possess specialized vocal learning abilities, similar to how humans learn to speak. This involves complex brain structures that allow them to process, remember, and reproduce sounds.\n* **Understanding Context (to an extent):** While they don\'t understand language in the same way humans do, many parrots can learn to associate specific words or phrases with particular objects, actions, or people. For example, a parrot might learn to say "hello" when someone enters the room or "treat" when they see their favorite food. This demonstrates a level of contextual understanding.\n* **Problem-Solving:** Their intelligence allows them to figure out that vocalizations can be a tool to achieve desired outcomes, like getting a treat or more playtime.\n\n**3. Evolutionary Advantage:**\n\n* **Cooperative Breeding:** In some parrot species, cooperative breeding is observed, where non-breeding individuals help raise young. This requires strong communication within the family unit, and vocal learning could have played a role in developing more complex communication systems.\n* **Predator Evasion:** The ability to mimic sounds could also serve as a form of camouflage or distraction. By mimicking the sounds of predators or other animals, they might confuse or deter threats.\n\n**4. Learned Behavior and Reinforcement:**\n\n* **Positive Reinforcement:** In captivity, parrots learn that making specific sounds, especially human words, often results in positive reinforcement from their owners – praise, treats, attention, or playtime. This encourages them to repeat those sounds.\n* **Environmental Influence:** The sounds they are exposed to most frequently are the ones they are most likely to learn. This is why parrots kept in human households often pick up human speech.\n\n**In summary, parrots talk because:**\n\n* **They are highly social creatures who use vocalizations to communicate within their groups.**\n* **They are intelligent and possess the cognitive ability to learn and mimic sounds.**\n* **Talking can be a way to strengthen social bonds and seek attention.**\n* **They learn that certain sounds lead to positive outcomes (reinforcement).**\n\nIt\'s important to remember that not all parrots will talk, and the extent to which they do varies by species and individual. However, their ability to "talk" is a testament to their remarkable intelligence and their deep-seated need for social connection.'

# %% [markdown]
# ### Instead of using init_chat_model we can also use ChatOpenAI
#
# from langchain_openai import ChatOpenAI
#
# model=ChatOpenAI(model="gpt-4.1")
#
# response=model.invoke("Hello how are you")
#
# response

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
model=ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response=model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='Parrots talk for a fascinating combination of reasons, and it\'s not just about mimicking human sounds. Here\'s a breakdown of why they do it:\n\n**1. Social Bonding and Communication:**\n\n* **Wild Parrots:** In their natural habitats, parrots are highly social creatures that live in flocks. They use a complex system of vocalizations, including squawks, calls, and whistles, to communicate with each other. This communication is vital for:\n    * **Maintaining Flock Cohesion:** Keeping track of each other in dense foliage or during flight.\n    * **Warning of Danger:** Alerting the flock to predators.\n    * **Finding Food and Water:** Sharing information about resources.\n    * **Establishing Social Hierarchies:** Communicating their status within the flock.\n    * **Courtship and Mating:** Expressing interest and building bonds.\n* **Pet Parrots:** When kept as pets, parrots often see their human family as their flock. They learn to mimic human speech as a way to:\n    * **Integrate into the "Flock":** They are trying to be part of your social group and communicate in a way they understand you can respond to.\n    * **Gain Attention and Interaction:** Talking is a highly effective way to get your attention. If they see that vocalizing gets a positive response (even just looking at them), they\'ll repeat it.\n    * **Express Emotions:** While they don\'t understand the meaning of words in the same way we do, they can associate certain sounds with feelings or situations. For example, they might say "hello" when you come home or "goodnight" when it\'s dark.\n\n**2. Intelligence and Cognitive Abilities:**\n\n* **Exceptional Mimicry:** Parrots have highly developed vocal tracts and the cognitive ability to learn and reproduce a wide range of sounds. This isn\'t just rote memorization; they can learn complex patterns.\n* **Understanding Context (to a degree):** Some parrots, particularly African Greys, have demonstrated an impressive ability to learn the meanings of words and use them in appropriate contexts. This goes beyond simple mimicry and shows a level of cognitive understanding. They can learn to identify objects, colors, and even abstract concepts like "same" and "different."\n* **Problem-Solving:** Their intelligence allows them to figure out that vocalizations are a successful strategy for interaction and reward.\n\n**3. Natural Vocal Learners:**\n\n* **Vocal Learning is Key:** Parrots are classified as "vocal learners," meaning they learn their vocalizations by listening to others and practicing. This is a trait shared by only a few other animal groups, including humans, whales, and dolphins.\n* **Practice Makes Perfect:** Like human babies babbling, young parrots will often "babble" and experiment with sounds as they learn.\n\n**4. Reinforcement and Reward:**\n\n* **Positive Reinforcement:** When a parrot says something and receives a positive reaction from their owner (attention, treats, praise), they are more likely to repeat that behavior. This is a powerful learning mechanism.\n* **Curiosity and Exploration:** Parrots are naturally curious and enjoy exploring their environment, including the sounds they hear. Mimicking sounds is a way for them to interact with and understand their surroundings.\n\n**In summary, parrots talk because:**\n\n* **It\'s their natural way of communicating and bonding within a social group.**\n* **They are highly intelligent and capable of learning and mimicking sounds.**\n* **They are natural vocal learners who learn by listening and practicing.**\n* **They are often reinforced for vocalizing by their human companions.**\n\nIt\'s important to remember that while parrots can be incredibly impressive mimics, their understanding of language is different from ours. They are not having philosophical conversations, but they are certainly engaging in a form of communication and social interaction that is deeply ingrained in their nature.', additional_kwargs={}, response_metadat ...

# %%
### GROQ model integration
from langchain.chat_models import init_chat_model
model=init_chat_model("groq:llama-3.3-70b-versatile") #groq: whatever model we want
response=model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='Parrots are known for their ability to mimic human speech and other sounds, but why do they do it? The answer lies in their evolution, social behavior, and communication needs.\n\nIn the wild, parrots use vocalizations to communicate with each other for various purposes, such as:\n\n1. **Contact calls**: To maintain contact with their flock members, especially when foraging or flying.\n2. **Alarm calls**: To alert other parrots to potential predators or threats.\n3. **Courtship and mating**: To attract a mate or strengthen pair bonds.\n4. **Territorial defense**: To defend their territory from other parrots.\n\nParrots have a unique anatomy that allows them to produce a wide range of sounds, including human-like speech. Their syrinx, located at the base of the trachea, is a vocal organ that is capable of producing complex vocalizations.\n\nWhen parrots are kept as pets or in captivity, they often learn to mimic human speech as a way to:\n\n1. **Communicate with their human caregivers**: Parrots may learn to associate certain words or phrases with food, attention, or affection.\n2. **Imitate their environment**: Parrots are highly social and curious birds, and they may mimic sounds they hear in their environment, including human speech.\n3. **Express themselves**: Parrots may use vocalizations to express emotions, such as excitement, boredom, or frustration.\n\nSome interesting facts about parrot vocalizations:\n\n* African Greys are considered one of the best talking parrots, with some individuals learning to mimic hundreds of words and phrases.\n* Parrots can learn to mimic other sounds, such as car alarms, animal noises, or even music.\n* Some parrots are able to learn and use context-specific language, such as asking for food or attention.\n\nOverall, parrots talk because it is an essential part of their communication and social behavior, and they have evolved to use vocalizations to convey information, express themselves, and interact with their environment.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 406, 'prompt_tokens': 41, 'total_tokens': 447, 'completion_time': 1.6656134630000001, 'completion_tokens_details': None, 'prompt_time': 0.001979857, 'prompt_tokens_details': None, 'queue_time': 0.063632812, 'total_time': 1.66759332}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c06d5113ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1de8-b88c-7d72-80b8-be4c7a747ee1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 406, 'total_tokens': 447})

# %%
#Different way
from langchain_groq import ChatGroq
model=ChatGroq(model="llama-3.3-70b-versatile")
response=model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content="Parrots are known for their ability to mimic human speech and other sounds, but why do they do it? The answer lies in their evolution, social behavior, and communication needs.\n\n**Mimicry as a form of communication**\n\nIn the wild, parrots use vocalizations to communicate with each other. They have a wide range of calls, songs, and other sounds to convey messages, such as warning calls to alert other parrots to potential predators, contact calls to maintain social bonds, and courtship songs to attract a mate. Mimicry is an extension of this communication system, allowing parrots to learn and reproduce sounds they hear in their environment.\n\n**Social learning and bonding**\n\nParrots are highly social animals that live in flocks in the wild. They learn by observing and imitating each other, including their vocalizations. By mimicking human speech, parrots may be attempting to bond with their human caregivers or to initiate interaction. In the wild, parrots will often mimic the calls of other birds or even other species, like monkeys, to integrate themselves into the social group.\n\n**Brain structure and cognitive abilities**\n\nParrots have a large brain-to-body mass ratio, which is similar to that of primates and dolphins. This suggests that they have advanced cognitive abilities, including the capacity for complex vocal learning and mimicry. The syrinx, the vocal organ located at the base of the trachea in birds, is highly developed in parrots, allowing them to produce a wide range of sounds and vocalizations.\n\n**Attention seeking and reinforcement**\n\nIn captivity, parrots may learn to talk to get attention from their owners or to receive rewards, such as food or treats. When a parrot mimics human speech, it may be seeking to initiate interaction or to get a reaction from its owner.\n\n**Other theories**\n\nSome researchers believe that parrots may talk to:\n\n1. **Express themselves**: Parrots may use vocalizations to express emotions, such as happiness, boredom, or frustration.\n2. **Explore their environment**: By mimicking sounds, parrots may be trying to understand their surroundings and learn about the world around them.\n3. **Develop their vocal skills**: Talking may be a way for parrots to practice and improve their vocal abilities, which are essential for communication and social interaction.\n\nWhile we can't know for certain why individual parrots talk, it's likely that their motivations are complex and multifaceted, involving a combination of these factors.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 502, 'prompt_tokens': 41, 'total_tokens': 543, 'completion_time': 1.610634128, 'completion_tokens_details': None, 'prompt_time': 0.001984845, 'prompt_tokens_details': None, 'queue_time': 0.057452214, 'total_time': 1.612618973}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c06d5113ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1dea-28c4-7d21-80e7-7b70d400e057-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 502, 'total_tokens': 543})

# %% [markdown]
# ## Streaming And Batch
#
# #### Streaming
#
# Most models can stream their output content which is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yield output chunks as they are produced. You can loop to process each chunk in real time

# %%
model.invoke("Write me a 200 words paragraph on AI")
#it will take some time to generate
#we try to stream the output as soon as it is generated from the LLM
#here streaming is helpful
#instead of giving the final ouput all at once, it streams the output while it is being generated
# Out:
# AIMessage(content='Artificial intelligence (AI) has revolutionized the way we live, work, and interact with technology. This innovative field of computer science enables machines to think, learn, and act like humans, transforming industries and transforming the world. From virtual assistants like Siri and Alexa to self-driving cars and personalized product recommendations, AI is omnipresent in our daily lives. With its ability to process vast amounts of data, recognize patterns, and make decisions, AI has become an indispensable tool for businesses, healthcare, finance, and education. Moreover, AI-powered machines can perform tasks with greater accuracy, speed, and efficiency, freeing humans from mundane and repetitive work. As AI continues to evolve, we can expect even more groundbreaking applications, such as intelligent robots, autonomous drones, and advanced chatbots. However, as AI becomes increasingly sophisticated, it also raises important questions about job displacement, data privacy, and ethics, highlighting the need for responsible AI development and deployment. Overall, AI has the potential to unlock unprecedented opportunities for human progress, but it requires careful consideration and management to ensure that its benefits are realized while minimizing its risks. By harnessing the power of AI, we can create a brighter, more efficient, and more sustainable future.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 245, 'prompt_tokens': 44, 'total_tokens': 289, 'completion_time': 0.66057578, 'completion_tokens_details': None, 'prompt_time': 0.003687712, 'prompt_tokens_details': None, 'queue_time': 0.056569347, 'total_time': 0.664263492}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_68f543a7cc', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1def-ac4f-7230-90ba-9d3e8c8857e2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 245, 'total_tokens': 289})

# %%
#model.stream("Write me a 200 words paragraph on AI")
#this will create a generator object of type stream

# %%
for chunk in model.stream("Why do parrots have colourful feathers"):
    print(chunk.text,end="",flush=True) # end="" prevents newline after every word
# Out:
# Parrots are known for their vibrant and colorful feathers, which serve several purposes beyond just looking beautiful. Here are some reasons why parrots have colorful feathers:
#
# 1. **Communication and Expression**: Parrots use their colorful feathers to communicate with other parrots, convey emotions, and express their identity. Different colors and patterns can signal aggression, courtship, or friendliness.
# 2. **Mating and Attraction**: Brightly colored feathers can be an attractive feature for potential mates. Male parrots often have more vibrant colors than females, which helps them stand out and showcase their health, strength, and genetic quality.
# 3. **Camouflage and Disguise**: While it may seem counterintuitive, some parrots' colorful feathers can actually help them blend in with their surroundings. For example, the blue and yellow feathers of the Blue-and-yellow Macaw can help it blend in with the bright colors of the tropical flowers and fruits in its habitat.
# 4. **Thermoregulation**: The colorful feathers of parrots can also help regulate their body temperature. Darker colors absorb heat, while lighter colors reflect it. This helps parrots maintain a stable body temperature in varying environmental conditions.
# 5. **Social Status**: In some parrot species, colorful feathers can indicate social status or dominance. For example, the African Grey Parrot's gray feathers can turn pink or red on the face and belly of dominant birds.
# 6. **Warning Signals**: Some parrots have colorful feathers that serve as warning signals to potential predators. The bright colors and patterns can signal to predators that the parrot is toxic, distasteful, or otherwise unpalatable.
# 7. **Evolutionary Adaptation**: The colorful feathers of parrots have evolved over time to help them survive and thrive in their environments. The specific colors and patterns have been shaped by natural selection to provide the best possible advantages for the parrot's survival and reproduction.
# 8. **Visual Display**: Parrots use their colorful feathers to create visual displays, such as courtship displays or threat displays, which can help them establish dominance or attract a mate.
#
# In summary, the colorful feathers of parrots serve a range of purposes, from communication and mating to camouflage and thermoregulation. These vibrant feathers have evolved to provide parrots with a competitive edge in their environments and to help them thrive in their ecological niches.

# %% [markdown]
# ## Batch
#
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses=model.batch([
    "why do parrots have colourful feathers?",
    "How to airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# content="Parrots have colorful feathers for several reasons, including:\n\n1. **Communication and Expression**: Colorful feathers help parrots communicate with each other through visual displays. They use their bright plumage to express emotions, intentions, and social status. For example, a parrot may puff out its colorful feathers to signal aggression or courtship.\n2. **Mating and Attraction**: Vibrant feathers play a crucial role in attracting a mate. Parrots with more intense, vibrant, or unique coloration may be perceived as more attractive or healthy, increasing their chances of finding a mate.\n3. **Camouflage and Defense**: While it may seem counterintuitive, some parrots' colorful feathers can actually help them blend in with their surroundings. For example, the bright greens and blues of some parrot species can help them merge with the foliage of their rainforest habitats, making it harder for predators to spot them.\n4. **Social Status and Dominance**: In some parrot species, colorful feathers can indicate social status or dominance. For example, the sulfur-crested cockatoo's bright yellow crest is a sign of dominance and maturity.\n5. **Thermoregulation**: Some researchers believe that the colorful feathers of parrots may help regulate their body temperature. The pigments in their feathers can absorb or reflect sunlight, helping to keep them warm or cool, depending on the environment.\n6. **Evolutionary Adaptation**: The evolution of colorful feathers in parrots may have been driven by the availability of food resources. For example, parrots that lived in areas with abundant fruits and flowers may have developed bright colors to advertise their presence to other parrots, helping to establish a stable food source.\n7. **Genetic Variation**: Finally, the colorful feathers of parrots may simply be a result of genetic variation and random drift. As parrot populations evolved over time, genetic mutations that resulted in brighter, more vibrant feathers may have become fixed in certain species, leading to the stunning diversity of colors we see today.\n\nThese reasons are not mutually exclusive, and it's likely that the colorful feathers of parrots serve multiple purposes, depending on the species and the context." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 441, 'prompt_tokens': 43, 'total_tokens': 484, 'completion_time': 2.061254728, 'completion_tokens_details': None, 'prompt_time': 0.006228613, 'prompt_tokens_details': None, 'queue_time': 0.055268225, 'total_time': 2.067483341}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019c1df8-fe04-72b2-ae6b-8f37bfb89727-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 43, 'output_tokens': 441, 'total_tokens': 484}
# content="Airplanes fly by using a combination of four main forces: lift, weight, thrust, and drag. Here's a simplified explanation of how they work together to make an airplane fly:\n\n1. **Lift**: Lift is the upward force that opposes the weight of the airplane and keeps it flying. It's created by the shape of the wings, which are designed to produce a difference in air pressure above and below the wing. As the airplane moves forward, the air flowing over the curved surface of the wing creates a region of lower pressure above the wing and a region of higher pressure below it. This pressure difference creates an upward force called lift, which counteracts the weight of the airplane.\n2. **Weight**: Weight is the downward force that pulls the airplane towards the ground. It's the combined weight of the airplane itself, the passengers, cargo, and fuel.\n3. **Thrust**: Thrust is the forward force that propels the airplane through the air. It's created by the airplane's engines, which produce a stream of high-speed air that exits the back of the plane. As this air exits, it produces a forward force that pushes the airplane forward.\n4. **Drag**: Drag is the backward force that opposes the motion of the airplane. It's created by air resistance, which slows down the airplane as it moves through the air.\n\nWhen an airplane is in flight, these four forces are in balance:\n\n* Lift = Weight (the airplane is not climbing or descending)\n* Thrust = Drag (the airplane is not accelerating or decelerating)\n\nHere's how it works:\n\n1. The airplane's engines produce thrust, which propels the plane forward.\n2. As the plane moves forward, the air flows over and under the wings, creating lift.\n3. The lift opposes the weight of the airplane, keeping it flying.\n4. The drag created by air resistance slows down the airplane, but the thrust from the engines counters this force, keeping the plane moving forward.\n\nAdditionally, airplanes use control surfaces like ailerons, elevators, and rudders to control the direction of the plane and maintain stability during flight.\n\nIn summary, airplanes fly by using the shape of the wings to create lift, the engines to produce thrust, and the control surfaces to maintain stability and direction. The four forces of lift, weight, thrust, and drag work together to keep the airplane flying smoothly and efficiently." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 490, 'prompt_tokens': 40, 'total_tokens': 530, 'completion_time': 1.083787632, 'completion_tokens_details': None, 'prompt_time': 0.004219171, 'prompt_tokens_details': None, 'queue_time': 0.052174759, 'total_time': 1.088006803}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019c1df8-fe07-7203-84c4-6666bf207e47-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 490, 'total_tokens': 530}
# content='Quantum computing is a revolutionary technology that uses the principles of quantum mechanics to perform calculations and operations on data. It\'s a new paradigm for computing that has the potential to solve complex problems that are currently unsolvable or require an unfeasible amount of time to solve using classical computers.\n\n**Classical computing vs. Quantum computing:**\n\nClassical computers use bits to represent information, which can have a value of either 0 or 1. These bits are used to perform calculations and operations using logical gates. However, as the number of bits increases, the number of possible calculations grows exponentially, making it difficult to solve complex problems.\n\nQuantum computers, on the other hand, use quantum bits or qubits, which can exist in multiple states simultaneously, represented by a combination of 0 and 1. This property, known as superposition, allows qubits to process multiple possibilities simultaneously, making quantum computers potentially much faster than classical computers for certain types of calculations.\n\n**Key features of quantum computing:**\n\n1. **Superposition:** Qubits can exist in multiple states (0, 1, and both) at the same time, allowing for parallel processing of multiple possibilities.\n2. **Entanglement:** Qubits can become "entangled," meaning their properties are connected, even when separated by large distances. This enables quantum computers to perform calculations on multiple qubits simultaneously.\n3. **Quantum gates:** Quantum computers use quantum gates, which are the quantum equivalent of logical gates in classical computing. These gates perform operations on qubits, such as adding, multiplying, or rotating them.\n4. **Quantum algorithms:** Quantum computers use specialized algorithms, such as Shor\'s algorithm and Grover\'s algorithm, which are designed to take advantage of the unique properties of qubits.\n\n**Potential applications:**\n\n1. **Cryptography:** Quantum computers can potentially break many encryption algorithms currently in use, but they can also be used to create unbreakable quantum encryption methods.\n2. **Optimization:** Quantum computers can be used to optimize complex systems, such as logistics, finance, and energy management.\n3. **Simulation:** Quantum computers can simulate complex systems, such as molecules and materials, which can lead to breakthroughs in fields like chemistry and materials science.\n4. **Machine learning:** Quantum computers can be used to speed up certain machine learning algorithms, leading to improvements in areas like image recognition and natural language processing.\n\n**Current state and challenges:**\n\nWhile quantum computing has made significant progress in recent years, it\'s still an emerging technology. Currently, most quantum computers are small-scale and prone to errors, known as quantum noise. To build a large-scale, reliable quantum computer, significant technical challenges need to be overcome, such as:\n\n1. **Scalability:** Increasing the number of qubits while maintaining control and reducing errors.\n2. **Error correction:** Developing methods to correct errors that occur during quantum computations.\n3. **Quantum control:** Maintaining control over qubits and quantum gates to ensure accurate calculations.\n\nDespite these challenges, many organizations, including Google, IBM, Microsoft, and startups like Rigetti Computing, are actively working on developing quantum computing technology. As research and development continue to advance, we can expect to see significant breakthroughs in the field of quantum computing.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 664, 'prompt_tokens': 40, 'total_tokens': 704, 'completion_time': 2.150839261, 'completion_tokens_details': None, 'prompt_time': 0.005464453, 'prompt_tokens_details': None, 'queue_time': 0.058374677, 'total_time': 2.156303714}, 'model_name': 'llama-3.3-70b-versatile', 'system_finger ...

# %%
model.batch([
    "why do parrots have colourful feathers?",
    "How to airplanes fly?",
    "What is quantum computing?"],
    config={
        'max_concurrency':5, #Limit to 5 parallel calls
    }
)
# Out:
# [AIMessage(content='Parrots have colorful feathers for several reasons, including:\n\n1. **Communication and Expression**: Brightly colored feathers help parrots communicate with each other, express emotions, and convey information about their identity, sex, age, and social status. Different colors can signal aggression, courtship, or friendship.\n2. **Mating and Attraction**: Vibrant feathers play a crucial role in attracting a mate. Many parrot species have brightly colored plumage, which helps them stand out and signal their suitability as a partner. The more vibrant and intense the colors, the more attractive the parrot may be to a potential mate.\n3. **Camouflage and Defense**: While it may seem counterintuitive, some parrots\' bright colors can actually serve as camouflage in their natural environments. For example, the bright greens and blues of some parrot species can help them blend in with the foliage and sky of their tropical habitats. Additionally, bright colors can be used to distract or startle predators, giving the parrot an advantage in defense.\n4. **Thermoregulation**: Some research suggests that the colorful feathers of parrots may help regulate their body temperature. The darker, more pigmented feathers can absorb heat, while the lighter, more reflective feathers can reflect heat and help keep the parrot cool.\n5. **Evolutionary Advantage**: The evolution of colorful feathers in parrots may have been driven by the need to stand out in a competitive environment. In the wild, parrots often live in large flocks, and bright colors can help individuals establish dominance, attract mates, or signal their presence to other parrots.\n6. **Visual Display**: Parrots use their colorful feathers to create visual displays, such as courtship displays, threat displays, or alarm calls. These displays help parrots convey information and establish social bonds with other parrots.\n\nSome interesting facts about parrot feathers:\n\n* Parrots have a unique feather structure, with a central shaft (rachis) and vanes (barbs) that zip together to form a strong, yet lightweight, feather.\n* The colors of parrot feathers are created by the structure of the feathers themselves, as well as by pigments such as melanin, carotenoids, and psittacofulvins.\n* Parrots have a special type of feather called a "powder down" feather, which helps to keep their feathers clean and water-repellent.\n\nOverall, the colorful feathers of parrots are an essential part of their biology, behavior, and ecology, and play a vital role in their survival and success in the wild.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 528, 'prompt_tokens': 43, 'total_tokens': 571, 'completion_time': 1.5666856820000001, 'completion_tokens_details': None, 'prompt_time': 0.003962236, 'prompt_tokens_details': None, 'queue_time': 0.062856633, 'total_time': 1.5706479180000001}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c06d5113ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1dfb-dc12-7dc3-b10a-7d16e14425b4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 528, 'total_tokens': 571}),
#  AIMessage(content="Airplanes fly by using a combination of four main forces: lift, weight, thrust, and drag. Here's a simplified explanation of how these forces work together to make an airplane fly:\n\n1. **Lift**: Lift is the upward force that opposes the weight of the plane and keeps it flying. Lift is created by the shape of the wings, which are designed to produce a difference in air pressure above and below the wing. As the plane moves forward, the air flows over and under the curved surface of the wing, creating an area of lower pressure above the wing and an area of higher pressure below it. This pressure difference creates an upward force called lift, which counteracts the weight of the plane.\n2. **Weight**: Weight is the downward force that pulls the plane towards the ground. It's the combined weight of the plane itself, the passengers, cargo, and fuel.\n3. **Thrust**: Thrust is the forward force that propels the plane through the air. It's created by the plane's engines, which produce a stream of high-speed air that exits the back of the plane. As this air is expelled, it produces a forward force that counteracts the drag (resistance) created by the air.\n4. **Drag**: Drag is the backward force that opposes the motion of the plane. It's created by the air resistance that the plane encounters as it moves forward. Drag is affected by the shape of the plane, its speed, and the density of the air.\n\nWhen an airplane is in flight, the four forces are in balance:\n\n* Lift equals weight (the plane is not rising or falling)\n* Thrust equals drag (the plane is not speeding up or slowing down)\n\nTo generate lift, airplanes use a combination of:\n\n* **Wing shape**: The curved upper surface of the wing deflects the air downward, creating a region of lower pressure above the wing.\n* **Angle of attack**: The wing is angled slightly upward, which creates a swirling motion behind the wing that helps to increase lift.\n* **Airfoil shape**: The wing is shaped like an airfoil, with a curved upper surface and a flat lower surface. This shape helps to create the pressure difference that generates lift.\n\nTo generate thrust, airplanes use:\n\n* **Jet engines**: These engines produce a high-speed exhaust gas that exits the back of the plane, creating a forward force.\n* **Propellers**: These are spinning blades that push air backward, creating a forward force.\n\nBy adjusting the angle of attack, throttle setting, and other control surfaces, pilots can control the balance of these forces and navigate the plane through the air.\n\nI hope that helps! Let me know if you have any further questions.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 550, 'prompt_tokens': 40, 'total_tokens': 590, 'completion_time': 1.237689968, 'completion_tokens_details': None, 'prompt_time': 0.004707071, 'prompt_tokens_details': None, 'queue_time': 0.064272339, 'total_time': 1.242397039}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c06d5113ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c1dfb-dc15-7843-a899-a56f6824b437-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 550, 'total_tokens': 590}),
#  AIMessage(content='Quantum computing is a revolutionary technology that uses the principles of quantum mechanics to perform calculations and operations on data. It\'s a new paradigm for computing that has the potential to solve complex problems that are currently unsolvable or require an unfeasible amount of time to solve using classical computers.\n\n**Classical vs. Quantum Computing**\n\nClassical computers use bits to store and process information, which can have a value of either 0 or 1. These bits are used to perform calculations and operations using logical gates, which are the basic building blocks of digital circuits. However, as the number of bits increases, the number of possible calculations and operations grows exponentially, making it difficult to solve complex problems.\n\nQuantum computers, on the other hand, use quantum bits or qubits, which can exist in multiple states simultaneously, represented by a combination of 0 and 1. This property, known as superposition, allows qubits to process multiple possibilities simultaneously, making quantum computers potentially much faster than classical computers for certain types of calculations.\n\n**Key Features of Quantum Computing**\n\n1. **Superposition**: Qubits can exist in multiple states (0, 1, and both) at the same time, allowing for parallel processing of multiple possibilities.\n2. **Entanglement**: Qubits can become "entangled," meaning that the state of one qubit is dependent on the state of another, even if they are separated by large distances.\n3. **Quantum parallelism**: Quantum computers can perform many calculations simultaneously, thanks to the principles of superposition and entanglement.\n4. **Quantum gates**: Quantum computers use quantum gates, which are the quantum equivalent of logical gates, to manipulate qubits and perform operations.\n\n**Applications of Quantum Computing**\n\nQuantum computing has the potential to revolutionize various fields, including:\n\n1. **Cryptography**: Quantum computers can break certain types of classical encryption, but they can also be used to create unbreakable quantum encryption methods.\n2. **Optimization**: Quantum computers can be used to solve complex optimization problems, such as finding the shortest path in a network or the most efficient way to schedule tasks.\n3. **Simulation**: Quantum computers can simulate complex systems, such as molecules and chemical reactions, which could lead to breakthroughs in fields like medicine and materials science.\n4. **Machine learning**: Quantum computers can be used to speed up certain machine learning algorithms, leading to improved performance and efficiency.\n\n**Current State and Challenges**\n\nWhile quantum computing has made significant progress in recent years, it\'s still in its early stages. Currently, most quantum computers are small-scale and noisy, meaning that they are prone to errors due to the fragile nature of qubits. To overcome these challenges, researchers are working on developing more robust and scalable quantum computing architectures, as well as improving error correction techniques.\n\nIn summary, quantum computing is a new and exciting field that has the potential to solve complex problems that are currently unsolvable or require an unfeasible amount of time to solve using classical computers. While it\'s still in its early stages, the potential applications and benefits of quantum computing are vast and could lead to breakthroughs in various fields.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 638, 'prompt_tokens': 40, 'total_tokens': 678, 'completion_time': 1.341107212, 'completion_tokens_details': None, 'prompt_time': 0.003724047, 'prompt_tokens_details': None, 'queue_time': 0.057159563, 'total_time': 1.344831259}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c06d5113ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01 ...
